# %% [markdown]
# # Week 13:  Object-oriented programming HW

# %% [markdown]
# ## Exercise 1  (from Monday's class)

# %% [markdown]
# 1. Write a ``Particle`` class that can be used to represent a particle with a mass, a 3-d position, and a 3-d velocity.
#
# 2. Write a method that can be used to compute the kinetic energy of the particle
#
# 3. Write a method that takes another particle as an argument and finds the distance between the two particles
#
# 4. Write a method that given a time interval ``dt`` will update the position of the particle to the new position based on the current position and velocity.
#
# 5. Write a ``ChargedParticle`` class that inherits from the ``Particle`` class, but also has an attribute for the charge of the particle.

# %%
import numpy as np
# your solution here

class ChargedParticle(Particle):

    def __init__(self,mass, x, y, z, vx, vy, vz, charge):
        self.mass = mass
        self.x = x
        self.y = y
        self.z = z
        self.vx = vx
        self.vy = vy
        self.vz = vz
        self.charge = charge

# %%
# write/copy code here
import numpy as np

class Particle(object):
    def __init__(self, x, y, z, x_vel, y_vel, z_vel, mass):
        self.x = x
        self.y = y
        self.z = z
        self.x_vel = x_vel
        self.y_vel = y_vel
        self.z_vel = z_vel
        self.mass = mass        
    def ke(self): # kinetic energy
        return self.mass*(self.x_vel**2 + self.y_vel**2 + self.z_vel**2)/2
    def dist(self, other): # dist between 2 particles
        return np.sqrt(((self.x - other.x)**2) + ((self.y - other.y)**2) + ((self.z - other.z)**2))
    def update_pos(self, dt): # update the postion based on time interval 'dt' and the x,y,z v's
        self.x += (self.x_vel*dt)
        self.y += (self.y_vel*dt)
        self.z += (self.z_vel*dt)
        print(f'old x: {self.x - (self.x_vel*dt)} old y: {self.y - (self.y_vel*dt)} old z: {self.z - (self.z_vel*dt)} \
            \n new x: {self.x} new y: {self.y} new z: {self.z}')
        
class ChargedParticle(Particle):
    def __init__(self, x, y, z, x_vel, y_vel, z_vel, mass, charge):
        super().__init__(x, y, z, x_vel, y_vel, z_vel, mass)
        self.charge = charge    
    def what_charge(self):
        if self.charge > 0:
            val = 'positive charge'
        elif self.charge < 0:
            val = 'negative charge'
        else:
            val = 'neutral charge'
        print(f'the particle has a {val}')

# %% [markdown]
# ## Exercise 2  (New)

# %% [markdown]
# 6. Write a method that can be used to see if a particle is in the same place (e.g., find_seperation < 0.25).  If there are two ChargedParticles in the same place make a "simple" (not correct physics) "interaction". (__have the code print "interaction"__).
#
#     a. If the charges are opposite, make them "combine", set both velocities to zero and set their charge to zero, and print "merge".
#
#     b. Else, make the particles "repel", to do:
#
#         multiply each "self" velocity and  by (-1 * (self.charge+other.charge) * (self.mass/other.mass))
#
#         multiply each "other" velocity by (-1 * (self.charge+other.charge) * (other.mass/self.mass))
#
#     e.g., reversing it's velocity, and print "repel". __(Again this is bad physics, but we are focusing on coding so play along.)__
#
#
# 7. To test the above, write a code with two particles starting:
#
#         P1 at (x,y,z) = (-5,-5,-5) with (vx,vy,vz) = (1,1,1) and (charge = 0.5)
#
#         P2 at (x,y,z) = (5,5,5) with (vx,vy,vz) = (-1,-1,-1) and (charge = -0.5).
#
#     Use your dt time interval to move the particles in 0.5 time steps for 50 steps, and print the current poition and velocity of each particle at each time step.
#
#
# 8. To test the above, write a code with two particles starting:
#
#         P1 at (x,y,z) = (-5,-5,-5) with (vx,vy,vz) = (2,2,2) and (charge = 0.5)
#
#         P2 at (x,y,z) = (5,5,5) with (vx,vy,vz) = (-2,-2,-2) and (charge = 2.0).
#
#     Use your dt time interval to move the particles in 0.5 time steps for 50 steps, and print the current poition and velocity of each particle at each time step.

# %%
# write new code here
import numpy as np 
from colorama import Fore # make colors yay

class Particle(object):
    def __init__(self, x, y, z, x_vel, y_vel, z_vel, mass):
        self.x = x
        self.y = y
        self.z = z
        self.x_vel = x_vel
        self.y_vel = y_vel
        self.z_vel = z_vel
        self.mass = mass        
    def ke(self): # kinetic energy
        return self.mass*(self.x_vel**2 + self.y_vel**2 + self.z_vel**2)/2
    def dist(self, other): # dist between 2 particles
        return np.sqrt(((self.x - other.x)**2) + ((self.y - other.y)**2) + ((self.z - other.z)**2))
    def update_pos(self, dt): # update the postion based on time interval 'dt' and the x,y,z v's
        self.x += (self.x_vel*dt)
        self.y += (self.y_vel*dt)
        self.z += (self.z_vel*dt)
        print(Fore.BLACK + f'old x: {self.x - (self.x_vel*dt)} old y: {self.y - (self.y_vel*dt)} old z: {self.z - (self.z_vel*dt)} \
            \n new x: {self.x} new y: {self.y} new z: {self.z}')
        
class ChargedParticle(Particle):
    def __init__(self, x, y, z, x_vel, y_vel, z_vel, mass, charge):
        super().__init__(x, y, z, x_vel, y_vel, z_vel, mass)
        self.charge = charge    
    def what_charge(self):
        if self.charge > 0:
            val = 'positive charge'
        elif self.charge < 0:
            val = 'negative charge'
        else:
            val = 'neutral charge'
        print(f'the particle has a {val}')
    def seperation(self, other):
        if (np.sqrt(((self.x - other.x)**2) + ((self.y - other.y)**2) + ((self.z - other.z)**2)) <= 0.25):
            print('interaction')
            if (self.charge > 0 and other.charge < 0) or (self.charge < 0 and self.charge > 0):
                self.x_vel = 0
                self.y_vel = 0
                self.z_vel = 0
                other.x_vel = 0
                other.y_vel = 0
                other.z_vel = 0
                print('merge!')
            else:
                self.x_vel *= (-1 * (self.charge + other.charge) * (self.mass/other.mass))
                self.y_vel *= (-1 * (self.charge + other.charge) * (self.mass/other.mass))
                self.z_vel *= (-1 * (self.charge + other.charge) * (self.mass/other.mass))
                other.x_vel *= (-1 * (self.charge + other.charge) * (self.mass/other.mass))
                other.y_vel *= (-1 * (self.charge + other.charge) * (self.mass/other.mass))
                other.z_vel *= (-1 * (self.charge + other.charge) * (self.mass/other.mass))
                print('repel!')

# %%
# define the particles
p1 = ChargedParticle(-5, -5, -5, 1, 1, 1, 5, 0.5)
p2 = ChargedParticle(5, 5, 5, -1, -1, -1, 10, -0.5)
p3 = ChargedParticle(-5, -5, -5, 2, 2, 2, 5, 0.5)
p4 = ChargedParticle(5, 5, 5, -2, -2, -2, 10, 2)

#iterate 50 position updates with dt of .5 and print it
for i in range(50):
    print(Fore.RED + f'PARTICLE #1, STEP NUMBER: {i+1}')
    p3.update_pos(.5)
    print(Fore.RED + f'PARTICLE #2, STEP NUMBER: {i+1}')
    p3.update_pos(.5)
    p3.seperation(p4)
# Out:
# PARTICLE #1, STEP NUMBER: 1
